# %% [markdown]
# # Python for Digital Marketers

# %% [markdown]
# ## Introduction
#
# Python has gained popularity in the last decade due to several reasons, such as ease of learning the programming language, versatile fields of application, a huge package ecosystem, and more importantly, because it is the de facto language for data science and machine learning.
#
# Digital marketers have been leveraging these developments to improve their marketing campaigns and gain business insights to improve their growth.
#
# In this chapter, we will discuss how to get ready with Python. Throughout, we will use vanilla Python from the python.org website. You will also learn "How to set up Python on your operating system of choice?" and "How to setup Jupyter-Lab". You should be able to conduct all the exercises on "Jupyter-Lab".

# %% [markdown]
# ##  How Computer Works?
# - Examples of 7 Segement
# - Switches and Binary System
# - How Content is renderd on Screen?
# - How Operating Works?
#     - What are differnet operating Systems?
#         - Windows
#         - Linux
#         - BSD
#         - Android
#         - OSX
#     - Why we have different operating Systems?
#     - How to Choose Operating Sytem?

# %% [markdown]
# ## What is a Computer Program?
#
# - Set of Instructions to perform any task
# - Types of Computer Programs
#     - Application Programs
#         - Chrome Browser
#         - MS OFfice  (Excel & Power Points)
#     - Tailor Made/Custom Programs
#         - Zoom
#         - Grammerly
#         - Quilbot
#         - Screaming Frog

# %% [markdown]
# ## Different Types of User Interfaces
#
# - CLI (Command Line)
# - GUI (Graphical User Interface)
# - chatUX

# %% [markdown]
# ## What is a Programming Language?
#
# Language is a way to communicate with others. Like communication between humans, we also need a way to communicate with computers and machines. However, machines only understand bits and bytes, and it is hard to program with individual bits.
#
#
# To overcome this, computer scientists have developed programming languages to communicate with and give instructions to a computer. These languages have been divided into several categories.
#
#
# ### Lower Level Programming Languages
#
# - Bits
# - Assembly Language
#
# ###  Higher Level Programming Languages
#
# A human can understand and interpret these languages without getting too deep into individual bits. Many programming languages offer features, e.g., a garbage collector, type casting, etc., without any additional effort.
#
# There are thousands of languages invented in computing history. Most notable are Lisp and FORTRAN from early computer programming days. More languages have been developed in recent years, but they still borrow programming concepts from those old computer languages invented in the 1960s and 1970s.
#
# It is no wonder that modern programming languages like Python, Javascript, Ruby, Perl, and Closure are highly influenced by LiSP which was invented as a List Processing language.
# - Task Oreinted
# - General Purpose

# %% [markdown]
# ## Python as a Programming Language
#
# Python is a high-level programming language. It is very easy to learn and has human-readable syntax. Python scripts can be executed in almost all operating systems without additional configuration, e.g., Windows, Linux, Unix, Android, and even in browsers.
#
# Python has several advantages over its rivals and competitors, e.g., MATLAB, Julia, and R-Lang. Python can be used in different areas.
#
# ### Web Development
#
# You can use Python for web development. It is possible to use Python for both dynamic and static
#
# Plone, a python-based content management system, can be used for regular content management system tasks. You can use Jinja2 as a templating engine to generate HTML pages. A plethora of open-source static site generators are written in Python, e.g., Pelican, Lektor, and MkDocs.
#
# Flask and FASTAPI are quite popular for API development tasks in Python. You can also deploy them as lambda functions of servers, e.g., Vercel.
#
# Flask, Django, Bottle, and Web2py are popular web development frameworks for Python users.
#
# If you are looking for a Python alternative to Javascript to run scripts in a browser, then you will love the Brython Python package.
#
#
# ### App Development
#
# Python can be used to create desktop and mobile applications (for Android and Apple). Kivy is the most popular GUI framework for such tasks. You can also use QML for app development tasks.
#
# ## Application Programming
#
# You can create application programs in Python, e.g., Dropbox, Spotify, and many others.
#
#
# ## Automation
#
# Most famous software also offers plugin development for extending functionalities using Python scripting, e.g., Blender for 3D or Excel with Python using the xlswings Python Package.

# %% [markdown]
# ## Why Python for Digital Marketers?
#
# Digital marketers can use Python for
#
# - Collecting data from multiple sources
# - Cleaning raw data
# - Write scripts and programs to extract useful insights.
# - Digital marketers can write apps using the Kivy Framework.
# - Digital marketers can automate their website development and deployment tasks by leveraging the power of Python.

# %% [markdown]
# ## How To Setup Python?
#
# Python has evolved over the last decade. Installing any recent version of Python is very simple, and you can install it with the default wizard.
#
# Some operating systems will include it by default, e.g., Apple OS X and Linux distributions. However, on Windows, you have to install it yourself.
#
# The Python interpreter was originally written in C, and CPython is the reference implementation for this purpose. There is another Python-based implementation known as PyPy. For most cases, you will only come across CPython, and the default Python distribution is more than enough for your tasks.
#
# ### How to Download Python?
#
# Basic Python, also known as Vanilla Python, is available from the official Python website (python.org/downloads). However, being an open-source programming language, there are several other distributions (backed by commercial companies) available for download. It is important to understand the differences and choose the appropriate distribution for your use cases.
#
# - (Vanilla) Python
# - Anaconda
# - WinPython
# - Active Python
# - Embedded Python, e.g., MicroPython
#
# ### Install Python
#
# You can download Python from relevant Python distributions. For this course, you only need to download Python 3.10.11 from the official Python distribution website: https://www.python.org/downloads/release/python-31011/. Scroll down to the bottom of the page and download it for your operating system.
#
# #### Windows
# For Windows, most of you will probably need to download **Windows installer (64-bit)**.
# Click on this installer and follow the wizard. On the Installer start page, do not forget to check the checkbox for Add to System Path.
# Keep clicking "next," and your Python will be installed.
#
# #### Linux/Unix
#
# Python will be the default language for most Linux and Unix distributions. If your Python version is outdated and you want to update it, then follow the guidelines from your respective Linux distribution.
#
# #### OSX
#
# Mac OS X will come pre-installed with the Python version. If you need to install any specific version, then please download it from https://www.python.org/downloads/macos/. You might want to explore more options with homebrew and other managers.
#
#
# #### Mobile Phone
# You can also install Python on your mobile phone for learning on the go. Go to the respective app store and search for Python keywords.
#
# - Google Play
# On the Google Play store, you will find relevant apps, e.g., Pydroid. I have tested Pydroid, and it works like a charm.
#
# - Apple Store - IOS
# On the Apple App Store, you will find apps such as Python3IDE and Pyto. I have not tried these apps by myself, so this is not a formal recommendation.

# %% [markdown]
# ## What is Python Environment?
#
# - Why we need Vitual Environment?
# - What are Vitual Environment?
#     - venv
#     - conda
# - How to Create Virutal environment?
# - How to activate Virtual Environment?
# - How to deactivate virtual environment?

# %% [markdown]
# ## What are package managers?
#
# ### PIP
# We will only use this one, which is popular with standard Python.
#
# ### Conda
#
# Conda is also a package manager and is used as the default backend for Anaconda.
#
# ### PIPEnv
#
# It uses PIP and the virtual environment as a single command.
#
# ### Peotry
#
# Another package manager, which has gained popularity in recent years.

# %% [markdown]
# ## What are Python Packages?
#
# - like apps with additional feature
# - Offical Python Packages
#   - All Packages are avialble on https://pypi.org/ which contains metadata/information about the python packages.
#   - All Package files are stored and download from https://files.pythonhosted.org/
#   - You can install it using `pip install package-name`
#
#
# ###  Conda Package Distribution
# - Conda pacakges are available on https://conda-forge.org/feedstock-outputs/
# - You can install them using `conda install package-name`

# %% [markdown]
# ## What is iPython?
#
# - Vanila Python Command Line is not interactive
# - To make interactive use
#
# ### IPython Project
# - Development of iPython (Qt Widget, PyQMZ, Paralell Computing, Sockets, etc)
# - Python backend to the Jupyter Notebook (kernel)
# - interactive Python shell.
#
# ### The Big Split - Birth of Jupyter
#
# Julia, Python and R (JuPyterR)
#
# - Jupyter Note Book
# - Jupyter-lab (this is main)
# - Code reproducebalitiy

# %% [markdown]
# ## Getting Started With Python
#
#
# ### What is REPL
#
# - Read
# - Evaluate
# - Print
# - Loop
#
# ### Basic Commands
#
# #### Numbers
#
# - Bracket
# - Division
# - Multiplication
# - Plus
# - Minus
#
# #### Strings
#
# - Single Quotes
# - Double
# - Tripple
#
# #### Variables
# - Values
# - Name
# - Address
